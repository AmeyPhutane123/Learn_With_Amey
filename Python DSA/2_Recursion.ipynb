# %% [markdown]
# Stack overflow happens when a function get called infinite times and is not getting terminated

# %%
def fun1():
    fun2()
    print('Fin1')

def fun2():
    print('Fun2')

fun1()

# function inside another function
# this all works like a stack, function which is called later will be executed first and only then the other operation is completed.
# Out:
# Fun2
# Fin1
