# %%
mystr = 'AmeyemA'
ispalindrome = True

for i in range(((len(mystr)+1)//2)):
    if mystr[i] == mystr[len(mystr)-i-1] :
        continue
    else:
        ispalindrome = False
        break

print(ispalindrome)
# Out:
# True

# %%
mystr = 'AmeyemA'
len(mystr)
# Out:
# 7
