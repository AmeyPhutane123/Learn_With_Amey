# %%
x = 5
y = 9
z = 2
def func():
    x = 6 ## so this is like a temporary variable assignment
    global z 
    z = 10 # because we used global here, it changed original variable assignment
    print(y)
    print(x)
    print(z)
print(x)
print(z)
print(y)
func()
print(z)
print(x)
# Out:
# 5
# 2
# 9
# 9
# 6
# 10
# 10
# 5
