# %%
mystr = 'AmeyAnilPhutane'

ans = ""
for i in mystr:
    if ord(i)>=97:
        ans+=(chr(ord(i)-(ord('a')-ord('A'))))
    else:
        ans+=i
    
print(ans)
# Out:
# AMEYANILPHUTANE

# %%
ord('A')
# Out:
# 65

# %%
ord('a')
# Out:
# 97
