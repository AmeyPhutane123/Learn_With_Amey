# %% [markdown]
# # Basics of Programming in Python

# %% [markdown]
# #### Flowchart -
# - helps with problem solving.
#
# 1. Terminators - for start and stop
# 2. Parallelogram - for input output.
# 3. rectangle - process
# 4. kite - decision
#
# #### Pseudocode
# - writing solution

# %% [markdown]
# #### Variables & data Types
#
# - Variable is just a symbolic representation of some data.
# - Use Cases -
#     - changing code is easy.
#     - reusability of same variable at multiple places
#     - clearner code.
#
# - Data Types -
#     - Numeric:
#         - Integers
#         - Float
#         - Complex - 1+5j, 57+0j
#     - Sequential:
#         -

# %%
testVar = 1
print(testVar)
# Out:
# 1
